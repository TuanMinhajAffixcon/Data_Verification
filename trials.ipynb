# %%
import snowflake.connector
print(snowflake.connector.__file__)
# Out:
# d:\Users\dayax.affixcon\Desktop\Asian Data\app\Snowflake\snowflake\Lib\site-packages\snowflake\connector\__init__.py

# %%
hg21418.ap-south-1
https://hg21418.ap-south-1.aws.snowflakecomputing.com

# %%
conn = snowflake.connector.connect(
    user='TuanSeedin',
    password='J!2af!G1j',
    account='hg21418.ap-south-1',
    warehouse='COMPUTE_WH',
    database='DATA_VERIFICATION',
    schema='PUBLIC',
    role='ACCOUNTADMIN')

# %%
query = "SELECT * FROM DATA_VERIFICATION.PUBLIC.AU_RESIDENTIAL LIMIT 10"
cur = conn.cursor()
cur.execute(query)
df = cur.fetch_pandas_all()
df
# Out:
#    SOURCE_URN        GNAF_PID                   AD1   AD2           SUBURB  \
# 0     5952053  GANSW705240860        59 Foveaux Ave  None           LURNEA
# 1     9968932  GANSW717095208           1 Butler Rd  None         PEMULWUY
# 2     5655694  GANSW712101107         1 Church Cres  None          WINGHAM
# 3     8465361  GANSW705433943       372 Cordeaux Rd  None     MOUNT KEMBLA
# 4     6472402  GANSW705535899          25 Spring Rd  None  NORTH CURL CURL
# 5     6174618  GANSW705601158  Unit 3  49 Iberia St  None          PADSTOW
# 6     8125169  GANSW705756565       96 Elizabeth St  None       RIVERSTONE
# 7     8260160  GANSW705036259        68 Soldiers Rd  None          JANNALI
# 8     8814904  GANSW704930314         14 Morley Ave  None     HAMMONDVILLE
# 9     8784990  GANSW704944853      7 Chippendale Pl  None      HELENSBURGH
#
#   STATE  POSTCODE   STREETNAME STREETTYPE STREETSUFFIX  ...   SUR_NAME  \
# ...
